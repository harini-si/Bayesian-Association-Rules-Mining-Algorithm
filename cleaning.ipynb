# %%
import pandas as pd

df = pd.read_csv("data/breast-cancer.csv", header=None)

# %%
import seaborn as sns

# %%
df.columns = [
    "Class",
    "age",
    "menopause",
    "tumor-size",
    "inv-nodes",
    "node-caps",
    "deg-malig",
    "breast",
    "breast-quad",
    "irradiat",
]

# %%
df.head()
# Out:
#                   Class    age menopause tumor-size inv-nodes node-caps  \
# 0  no-recurrence-events  30-39   premeno      30-34       0-2        no
# 1  no-recurrence-events  40-49   premeno      20-24       0-2        no
# 2  no-recurrence-events  40-49   premeno      20-24       0-2        no
# 3  no-recurrence-events  60-69      ge40      15-19       0-2        no
# 4  no-recurrence-events  40-49   premeno        0-4       0-2        no
#
#    deg-malig breast breast-quad irradiat
# 0          3   left    left_low       no
# 1          2  right    right_up       no
# 2          2   left    left_low       no
# 3          2  right     left_up       no
# 4          2  right   right_low       no

# %%
# remove the rows with missing values
df.drop(df[df["node-caps"] == "?"].index, inplace=True)
df.drop(df[df["breast-quad"] == "?"].index, inplace=True)

# %%
df["node-caps"] = df["node-caps"].replace(["no"], "no_node_caps")
df["node-caps"] = df["node-caps"].replace(["yes"], "node_caps")
df["irradiat"] = df["irradiat"].replace(["no"], "no_irradiat")
df["irradiat"] = df["irradiat"].replace(["no"], "no_node_caps")

# %%
df.head()
# Out:
#                   Class    age menopause tumor-size inv-nodes     node-caps  \
# 0  no-recurrence-events  30-39   premeno      30-34       0-2  no_node_caps
# 1  no-recurrence-events  40-49   premeno      20-24       0-2  no_node_caps
# 2  no-recurrence-events  40-49   premeno      20-24       0-2  no_node_caps
# 3  no-recurrence-events  60-69      ge40      15-19       0-2  no_node_caps
# 4  no-recurrence-events  40-49   premeno        0-4       0-2  no_node_caps
#
#    deg-malig breast breast-quad     irradiat
# 0          3   left    left_low  no_irradiat
# 1          2  right    right_up  no_irradiat
# 2          2   left    left_low  no_irradiat
# 3          2  right     left_up  no_irradiat
# 4          2  right   right_low  no_irradiat

# %%
df.to_csv("data/bc.csv", index=False)

# %%
df1 = pd.read_csv("data/rules.csv", header=None)

# %%
df1[0:8]
# Out:
#                                         0                         1  \
# 0                                       A                         B
# 1                                 ['0-2']  ['no-recurrence-events']
# 2                        ['no_node_caps']  ['no-recurrence-events']
# 3                         ['no_irradiat']  ['no-recurrence-events']
# 4                  ['0-2', 'no_irradiat']  ['no-recurrence-events']
# 5         ['no_irradiat', 'no_node_caps']  ['no-recurrence-events']
# 6                 ['0-2', 'no_node_caps']  ['no-recurrence-events']
# 7  ['0-2', 'no_irradiat', 'no_node_caps']  ['no-recurrence-events']
#
#                    2                  3                    4  \
# 0            support         confidence  bayesian confidence
# 1  59.92779783393502  79.42583732057416    63.08463634074312
# 2  61.73285198555957  77.37556561085972     59.8697815360046
# 3   59.2057761732852  76.27906976744185    58.18496484586263
# 4  53.06859205776173  81.66666666666667    54.46712962962963
# 5  54.51263537906137  80.74866310160428   52.650927031933406
# 6  57.76173285198556               80.0    51.20000000000001
# 7  52.34657039711191  82.38636363636364    46.07033154717088
#
#                     5
# 0       bayesian lift
# 1  0.8915532788972368
# 2  0.8461188512996568
# 3  0.8223079215461198
# 4  0.7697650462962963
# 5  0.7440972850941608
# 6  0.7235918367346938
# 7  0.6510960121717517
